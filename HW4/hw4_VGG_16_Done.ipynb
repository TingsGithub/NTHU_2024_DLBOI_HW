# %% [markdown]
# # Import Library

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import time
import torch
import torch.nn as nn
import torch.optim as optims
import torchvision.models as models
from torch.optim import lr_scheduler

from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.transforms.functional import InterpolationMode

import pandas as pd
import seaborn as sns
from collections import defaultdict
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from torch.utils.data import SequentialSampler

# !pip install torchmetrics
# !pip install --upgrade torchmetrics
import torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: numpy<2.0,>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.0+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (0.11.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->torchmetrics) (3.0.2)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: numpy<2.0,>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.0+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (0.11.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->torchmetrics) (3.0.2)

# %%
if torch.cuda.is_available():
  device = torch.device('cuda') # GPU
else:
  device = torch.device('cpu') # CPU

print(device)
gpu_count = torch.cuda.device_count()

print("Using", gpu_count, "GPUs")
print("CUDA is available:", torch.cuda.is_available())
# Out:
# cpu
# Using 0 GPUs
# CUDA is available: False

# %%
# train loop
def train_one_epoch(model, device, criterion, optimizer, train_data_loader):
    epoch_loss = []
    epoch_acc = []
    start_time = time.time()

    t_Labels = []
    t_Preds = []

    model.train()

    for batch_idx, (images, labels) in enumerate (train_data_loader):
        images = images.to(device)
        labels = labels.to(device).float()
        optimizer.zero_grad()
        preds = model(images)
        loss = criterion(preds, labels.unsqueeze(1))

        # Calculating Loss
        epoch_loss.append(loss.item())

        # Calculating Metrics
        predicts = (preds > 0.5).float()
        predicts = predicts.view(-1)
        predicts = predicts.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
        acc = accuracy_score(labels, predicts)

        epoch_acc.append(acc)

        t_Labels.extend(labels)
        t_Preds.extend(predicts)

        # Backpropagation
        loss.backward()
        optimizer.step()

    # Overall Epoch Results
    end_time = time.time()
    total_time = end_time - start_time

    epoch_loss = np.mean(epoch_loss)
    epoch_acc = np.mean(epoch_acc) * 100

    return epoch_loss, epoch_acc, total_time, t_Preds, t_Labels

# validation loop
def val_one_epoch(model, device, criterion, val_data_loader, best_acc, save):
    epoch_loss = []
    epoch_acc = []
    start_time = time.time()

    v_Labels = []
    v_Preds = []

    model.eval()

    with torch.no_grad():
        for images, labels in val_data_loader:
            images = images.to(device)
            labels = labels.to(device).float()
            preds = model(images)

            # Calculating Loss
            loss = criterion(preds, labels.unsqueeze(1))
            epoch_loss.append(loss.item())

            # Calculating Metrics
            predicts = (preds > 0.5).float()
            predicts = predicts.view(-1)
            predicts = predicts.detach().cpu().numpy()
            labels = labels.detach().cpu().numpy()
            acc = accuracy_score(labels, predicts)
            epoch_acc.append(acc)

            v_Labels.extend(labels)
            v_Preds.extend(predicts)

    # Overall Epoch Results
    end_time = time.time()
    total_time = end_time - start_time

    epoch_loss = np.mean(epoch_loss)
    epoch_acc = np.mean(epoch_acc) * 100

    # Saving best model
    if epoch_acc > best_acc:
        best_acc = epoch_acc
        torch.save(model.state_dict(), f"/content/drive/MyDrive/HW4_dataset/HW4_VGG16_model.pth")

    return epoch_loss, epoch_acc, total_time, best_acc, v_Preds, v_Labels

# evaluate loop (test loop)
def evaluate(model, device, model_path, test_loader):
    try:
        state_dict = torch.load(model_path, weights_only=True) # Prevent risks with untrusted pickle data.
        model.load_state_dict(state_dict)
        #model.load_state_dict(torch.load(model_path)) # TA's code
        print("Model weights loaded successfully.")
    except Exception as e:
        print("Warning: Failed to load model weights. Using randomly initialized weights instead.")
        print(e)

    model.to(device)
    model.eval()

    test_loss = []
    test_acc = []

    e_Labels = []
    e_Preds = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device).float()

            # Forward pass
            preds = model(images)

            # Calculating loss
            loss = criterion(preds, labels.unsqueeze(1))
            test_loss.append(loss.item())

            # Calculating accuracy
            predicts = (preds > 0.5).float()
            predicts = predicts.view(-1)
            predicts = predicts.detach().cpu().numpy()
            labels = labels.detach().cpu().numpy()
            acc = accuracy_score(labels, predicts)
            test_acc.append(acc)

            e_Labels.extend(labels)
            e_Preds.extend(predicts)

    # Overall test results
    avg_test_loss = np.mean(test_loss)
    avg_test_acc = np.mean(test_acc) * 100

    print(f"Test Accuracy: {avg_test_acc:.2f}%")
    print(f"Test Loss: {avg_test_loss:.4f}")

    return avg_test_loss, avg_test_acc, e_Preds, e_Labels

# %% [markdown]
# # Data Preparation

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# define folder path for each set
train_path = '/content/drive/MyDrive/HW4_dataset/train'
test_path = '/content/drive/MyDrive/HW4_dataset/test'
val_path = '/content/drive/MyDrive/HW4_dataset/val'

# define transformation
train_transform = transforms.Compose([
    transforms.Resize((256, 256), interpolation=InterpolationMode.BICUBIC),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
])

common_transform = transforms.Compose([
    transforms.Resize((256, 256), interpolation=InterpolationMode.BICUBIC),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
])

# create datasets
train_dataset = datasets.ImageFolder(train_path, transform=train_transform)
test_dataset = datasets.ImageFolder(test_path, transform=common_transform)
val_dataset = datasets.ImageFolder(val_path, transform=common_transform)

# create dataloaders
sampler_tr = SequentialSampler(train_dataset) # To make sure to more control over the dataloaders order
sampler_va = SequentialSampler(val_dataset) # To make sure to more control over the dataloaders order
sampler_te = SequentialSampler(test_dataset) # To make sure to more control over the dataloaders order
train_loader = DataLoader(train_dataset, batch_size=38, sampler=sampler_tr, shuffle=False) # TA's code shuffle=True
val_loader = DataLoader(val_dataset, batch_size=38, sampler=sampler_va, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=8, sampler=sampler_te, shuffle=False)

# %%
# Overview dataset
def analyze_dataset(dataloader):
  all_labels = []
  all_shapes = []
  for images, labels in dataloader:
    all_labels.extend(labels.tolist())
    for image in images:
      all_shapes.append(image.shape)

  label_counts = pd.Series(all_labels).value_counts()
  unique_shapes = set(all_shapes)

  return {
      "Number of Images": len(all_labels),
      "Number of Labels (Classes)": len(label_counts),
      "Label Counts": label_counts.to_dict(),
      "Unique Shapes": unique_shapes,
  }

train_stats = analyze_dataset(train_loader)
test_stats = analyze_dataset(test_loader)
val_stats = analyze_dataset(val_loader)

# Print the statistics for each dataset
print("Train Dataset Statistics:")
for key, value in train_stats.items():
  print(f"{key}: {value}")
print("\n")

print("Test Dataset Statistics:")
for key, value in test_stats.items():
  print(f"{key}: {value}")
print("\n")

print("Validation Dataset Statistics:")
for key, value in val_stats.items():
  print(f"{key}: {value}")
# Out:
# Train Dataset Statistics:
# Number of Images: 76
# Number of Labels (Classes): 2
# Label Counts: {0: 38, 1: 38}
# Unique Shapes: {torch.Size([3, 256, 256])}
#
#
# Test Dataset Statistics:
# Number of Images: 76
# Number of Labels (Classes): 2
# Label Counts: {0: 38, 1: 38}
# Unique Shapes: {torch.Size([3, 256, 256])}
#
#
# Validation Dataset Statistics:
# Number of Images: 16
# Number of Labels (Classes): 2
# Label Counts: {0: 8, 1: 8}
# Unique Shapes: {torch.Size([3, 256, 256])}

# %% [markdown]
# # Model

# %%
def initialize_model():
  # Load the pre-trained VGG16 model
  model = models.vgg16(pretrained=True)

  for param in model.parameters():
    param.requires_grad = False

  # Enable gradient computation only for the classifier
  for param in model.classifier.parameters():
    param.requires_grad = True

  # Modify the classifier for binary classification
  model.classifier[6] = nn.Sequential(
    nn.Linear(4096, 1),
    nn.Sigmoid()  # Add sigmoid activation
    )

  model = model.to(device)
  print(model)

  return model

# %% [markdown]
# # Loop

# %%
doe02 = pd.DataFrame(pd.read_csv('/content/drive/MyDrive/HW3_dataset/HW3_DOE_02.CSV'))
doe02.head()
# Out:
#    StdOrder  RunOrder  CenterPt  Blocks      lr  weight_decay  factor  \
# 0         8         1         1       1  0.0010        0.0010    0.10
# 1         2         2         1       1  0.0010        0.0001    0.01
# 2        16         3         1       1  0.0010        0.0010    0.10
# 3         6         4         1       1  0.0010        0.0001    0.10
# 4        13         5         1       1  0.0001        0.0001    0.10
#
#       criterion
# 0  nn.MSELoss()
# 1  nn.MSELoss()
# 2  nn.BCELoss()
# 3  nn.MSELoss()
# 4  nn.BCELoss()

# %%
# DOE FFD with 4 independent varaible and 1 block
summary = pd.DataFrame([])

for i in range(len(doe02)):
  model = initialize_model()  # Reset the model weights
  lr = doe02.iloc[i,4]
  weight_decay = doe02.iloc[i,5]
  factor = doe02.iloc[i,6]

  # criterion
  if doe02.iloc[i,7] == 'nn.MSELoss()':
    criterion = nn.MSELoss()
  elif doe02.iloc[i,7] == 'nn.BCELoss()':
    criterion = nn.BCELoss()

  optimizer = optims.Adam(model.parameters(), lr=lr, weight_decay = weight_decay)
  lr_scheduler = optims.lr_scheduler.ReduceLROnPlateau(optimizer, factor=factor, patience=3, mode='max') # TA's patience=5
  epochs = 10 # TA set defult epochs to 10

  # save checkpoint
  save = "/content/drive/MyDrive/HW4_dataset/HW4_VGG16_model.pth"

  # Initial for training
  train_losses = []
  val_losses = []
  train_accuracies = []
  val_accuracies = []

  best_acc = 0.0
  output_list = []

  # Training loop
  for epoch in range(epochs):
    train_loss, train_acc, train_time, train_p, train_l = train_one_epoch(model, device, criterion, optimizer, train_loader)
    val_loss, val_acc, val_time, best_acc, val_p, val_l = val_one_epoch(model, device, criterion, val_loader, best_acc, save)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    total_time = train_time + val_time
    output_str = f"Epoch {epoch+1}/{epochs} - loss: {train_loss:.4f} - train_acc: {train_acc:.2f}% - val_loss: {val_loss:.4f} - val_acc: {val_acc:.2f}% - time: {total_time:.2f}s"
    output_list.append(output_str)

    summary = pd.concat([summary, pd.DataFrame({
        "RunOrder": ['DOE RunOrder ' + str(i+1)],
        "Epoch": [epoch+1],
        "Train Loss": [train_loss],
        "Train Accuracy": [train_acc],
        "Val Loss": [val_loss],
        "Val Accuracy": [val_acc],
        "Total Time": [total_time],
        })])

    print('DOE RunOrder ' + str(i+1) , output_str)
    lr_scheduler.step(val_acc)

  # Graph
  plt.figure(figsize=(12, 5))

  # loss graph
  plt.subplot(1, 2, 1)
  plt.plot(train_losses, label='Train Loss')
  plt.plot(val_losses, label='Validation Loss')
  plt.title('DOE RunOrder ' + str(i+1) + ' Loss Curve')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()

  # accuracy graph
  plt.subplot(1, 2, 2)
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(val_accuracies, label='Validation Accuracy')
  plt.title('DOE RunOrder ' + str(i+1) + ' Accuracy Curve')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy (%)')
  plt.legend()

  # show
  plt.tight_layout()
  plt.show()

  # Evalute
  model_path = "/content/drive/MyDrive/HW4_dataset/HW4_VGG16_model.pth"
  avg_test_loss, avg_test_acc, eva_p, eva_l = evaluate(model, device, model_path, test_loader)

  # Plot precision-recall curve
  pr_curve = torchmetrics.PrecisionRecallCurve(task='binary')

  # Convert to tensors if they are lists
  train_p = torch.tensor(train_p) if isinstance(train_p, list) else train_p
  train_l = torch.tensor(train_l) if isinstance(train_l, list) else train_l
  val_p = torch.tensor(val_p) if isinstance(val_p, list) else val_p
  val_l = torch.tensor(val_l) if isinstance(val_l, list) else val_l
  eva_p = torch.tensor(eva_p) if isinstance(eva_p, list) else eva_p
  eva_l = torch.tensor(eva_l) if isinstance(eva_l, list) else eva_l

  # Convert to float32
  train_p = train_p.clone().detach() # Use clone and detach to create a copy of the tensor
  train_l = train_l.clone().detach().long() # Use clone and detach to create a copy of the tensor and convert to long
  val_p = val_p.clone().detach()  # Use clone().detach() to avoid unintended memory sharing
  val_l = val_l.clone().detach().long() # Use clone and detach to create a copy of the tensor and convert to long
  eva_p = eva_p.clone().detach()  # Use clone().detach() to avoid unintended memory sharing
  eva_l = eva_l.clone().detach().long() # Use clone and detach to create a copy of the tensor and convert to long

  precision_v, recall_v, thresholds_v = pr_curve(val_p, val_l)
  plt.figure()
  plt.step(recall_v, precision_v, where='post')
  plt.fill_between(recall_v, precision_v, step='post', alpha=0.2, color='b')
  plt.xlabel('Recall')
  plt.ylabel('Precision')
  plt.title('DOE RunOrder ' + str(i+1) + ' Val PR curve')
  plt.show()

  precision_e, recall_e, thresholds_e = pr_curve(eva_p, eva_l)
  plt.figure()
  plt.step(recall_e, precision_e, where='post')
  plt.fill_between(recall_e, precision_e, step='post', alpha=0.2, color='b')
  plt.xlabel('Recall')
  plt.ylabel('Precision')
  plt.title('DOE RunOrder ' + str(i+1) + ' Evaluate PR curve')
  plt.show()

summary.to_excel('/content/drive/MyDrive/HW4_dataset/DOE_summary_2024_DLBOI_HW4_113003803_VGG-16_03_Done03.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 1 Epoch 1/10 - loss: 0.5943 - train_acc: 40.79% - val_loss: 0.5000 - val_acc: 50.00% - time: 115.85s
# DOE RunOrder 1 Epoch 2/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 102.30s
# DOE RunOrder 1 Epoch 3/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.16s
# DOE RunOrder 1 Epoch 4/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.61s
# DOE RunOrder 1 Epoch 5/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.72s
# DOE RunOrder 1 Epoch 6/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 95.32s
# DOE RunOrder 1 Epoch 7/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 112.12s
# DOE RunOrder 1 Epoch 8/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.30s
# DOE RunOrder 1 Epoch 9/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 99.24s
# DOE RunOrder 1 Epoch 10/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.84s
# Model weights loaded successfully.
# Test Accuracy: 47.50%
# Test Loss: 0.5250
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 2 Epoch 1/10 - loss: 0.6447 - train_acc: 15.79% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.42s
# DOE RunOrder 2 Epoch 2/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 111.42s
# DOE RunOrder 2 Epoch 3/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.08s
# DOE RunOrder 2 Epoch 4/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.12s
# DOE RunOrder 2 Epoch 5/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.75s
# DOE RunOrder 2 Epoch 6/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.67s
# DOE RunOrder 2 Epoch 7/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.10s
# DOE RunOrder 2 Epoch 8/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 108.17s
# DOE RunOrder 2 Epoch 9/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.78s
# DOE RunOrder 2 Epoch 10/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.54s
# Model weights loaded successfully.
# Test Accuracy: 47.50%
# Test Loss: 0.5250
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 3 Epoch 1/10 - loss: 9.3711 - train_acc: 26.32% - val_loss: 0.6842 - val_acc: 50.00% - time: 100.60s
# DOE RunOrder 3 Epoch 2/10 - loss: 0.7660 - train_acc: 48.68% - val_loss: 0.6968 - val_acc: 50.00% - time: 101.10s
# DOE RunOrder 3 Epoch 3/10 - loss: 0.7901 - train_acc: 9.21% - val_loss: 0.6911 - val_acc: 50.00% - time: 96.29s
# DOE RunOrder 3 Epoch 4/10 - loss: 0.8033 - train_acc: 27.63% - val_loss: 0.6860 - val_acc: 50.00% - time: 105.24s
# DOE RunOrder 3 Epoch 5/10 - loss: 0.8539 - train_acc: 32.89% - val_loss: 0.6736 - val_acc: 68.75% - time: 99.71s
# DOE RunOrder 3 Epoch 6/10 - loss: 0.8866 - train_acc: 35.53% - val_loss: 0.6538 - val_acc: 62.50% - time: 101.36s
# DOE RunOrder 3 Epoch 7/10 - loss: 0.8848 - train_acc: 26.32% - val_loss: 0.6465 - val_acc: 56.25% - time: 98.42s
# DOE RunOrder 3 Epoch 8/10 - loss: 0.7770 - train_acc: 30.26% - val_loss: 0.6219 - val_acc: 62.50% - time: 97.92s
# DOE RunOrder 3 Epoch 9/10 - loss: 0.7225 - train_acc: 47.37% - val_loss: 0.5645 - val_acc: 87.50% - time: 97.40s
# DOE RunOrder 3 Epoch 10/10 - loss: 0.5786 - train_acc: 75.00% - val_loss: 0.4703 - val_acc: 93.75% - time: 111.55s
# Model weights loaded successfully.
# Test Accuracy: 56.25%
# Test Loss: 0.6794
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 4 Epoch 1/10 - loss: 0.6151 - train_acc: 31.58% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.70s
# DOE RunOrder 4 Epoch 2/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 100.93s
# DOE RunOrder 4 Epoch 3/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 99.41s
# DOE RunOrder 4 Epoch 4/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 95.20s
# DOE RunOrder 4 Epoch 5/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 108.15s
# DOE RunOrder 4 Epoch 6/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.55s
# DOE RunOrder 4 Epoch 7/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.19s
# DOE RunOrder 4 Epoch 8/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 100.92s
# DOE RunOrder 4 Epoch 9/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 96.92s
# DOE RunOrder 4 Epoch 10/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.74s
# Model weights loaded successfully.
# Test Accuracy: 47.50%
# Test Loss: 0.5250
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 5 Epoch 1/10 - loss: 1.2274 - train_acc: 2.63% - val_loss: 0.7299 - val_acc: 50.00% - time: 99.72s
# DOE RunOrder 5 Epoch 2/10 - loss: 0.6852 - train_acc: 50.00% - val_loss: 0.6285 - val_acc: 56.25% - time: 100.33s
# DOE RunOrder 5 Epoch 3/10 - loss: 0.5646 - train_acc: 75.00% - val_loss: 0.5830 - val_acc: 93.75% - time: 100.65s
# DOE RunOrder 5 Epoch 4/10 - loss: 0.5120 - train_acc: 90.79% - val_loss: 0.5547 - val_acc: 87.50% - time: 102.66s
# DOE RunOrder 5 Epoch 5/10 - loss: 0.4689 - train_acc: 92.11% - val_loss: 0.5166 - val_acc: 81.25% - time: 98.33s
# DOE RunOrder 5 Epoch 6/10 - loss: 0.4058 - train_acc: 90.79% - val_loss: 0.4534 - val_acc: 87.50% - time: 104.33s
# DOE RunOrder 5 Epoch 7/10 - loss: 0.3338 - train_acc: 92.11% - val_loss: 0.3715 - val_acc: 87.50% - time: 99.78s
# DOE RunOrder 5 Epoch 8/10 - loss: 0.2388 - train_acc: 97.37% - val_loss: 0.3637 - val_acc: 87.50% - time: 96.75s
# DOE RunOrder 5 Epoch 9/10 - loss: 0.2549 - train_acc: 94.74% - val_loss: 0.3559 - val_acc: 87.50% - time: 99.18s
# DOE RunOrder 5 Epoch 10/10 - loss: 0.2421 - train_acc: 96.05% - val_loss: 0.3482 - val_acc: 87.50% - time: 99.60s
# Model weights loaded successfully.
# Test Accuracy: 60.00%
# Test Loss: 0.6726
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 6 Epoch 1/10 - loss: 0.4693 - train_acc: 30.26% - val_loss: 0.3059 - val_acc: 50.00% - time: 109.27s
# DOE RunOrder 6 Epoch 2/10 - loss: 0.2966 - train_acc: 50.00% - val_loss: 0.2345 - val_acc: 50.00% - time: 99.39s
# DOE RunOrder 6 Epoch 3/10 - loss: 0.1936 - train_acc: 57.89% - val_loss: 0.2077 - val_acc: 75.00% - time: 98.51s
# DOE RunOrder 6 Epoch 4/10 - loss: 0.1611 - train_acc: 86.84% - val_loss: 0.2024 - val_acc: 81.25% - time: 101.42s
# DOE RunOrder 6 Epoch 5/10 - loss: 0.1550 - train_acc: 89.47% - val_loss: 0.1928 - val_acc: 75.00% - time: 103.49s
# DOE RunOrder 6 Epoch 6/10 - loss: 0.1314 - train_acc: 90.79% - val_loss: 0.1682 - val_acc: 81.25% - time: 98.42s
# DOE RunOrder 6 Epoch 7/10 - loss: 0.0981 - train_acc: 94.74% - val_loss: 0.1310 - val_acc: 87.50% - time: 104.46s
# DOE RunOrder 6 Epoch 8/10 - loss: 0.0816 - train_acc: 93.42% - val_loss: 0.1018 - val_acc: 87.50% - time: 103.02s
# DOE RunOrder 6 Epoch 9/10 - loss: 0.0594 - train_acc: 93.42% - val_loss: 0.0864 - val_acc: 87.50% - time: 97.38s
# DOE RunOrder 6 Epoch 10/10 - loss: 0.0451 - train_acc: 94.74% - val_loss: 0.0810 - val_acc: 87.50% - time: 98.82s
# Model weights loaded successfully.
# Test Accuracy: 56.25%
# Test Loss: 0.2660
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 7 Epoch 1/10 - loss: 0.4428 - train_acc: 10.53% - val_loss: 0.2812 - val_acc: 50.00% - time: 98.55s
# DOE RunOrder 7 Epoch 2/10 - loss: 0.2504 - train_acc: 50.00% - val_loss: 0.2376 - val_acc: 50.00% - time: 108.61s
# DOE RunOrder 7 Epoch 3/10 - loss: 0.1932 - train_acc: 67.11% - val_loss: 0.2130 - val_acc: 75.00% - time: 100.26s
# DOE RunOrder 7 Epoch 4/10 - loss: 0.1600 - train_acc: 88.16% - val_loss: 0.1992 - val_acc: 81.25% - time: 101.06s
# DOE RunOrder 7 Epoch 5/10 - loss: 0.1416 - train_acc: 90.79% - val_loss: 0.1859 - val_acc: 81.25% - time: 101.19s
# DOE RunOrder 7 Epoch 6/10 - loss: 0.1206 - train_acc: 93.42% - val_loss: 0.1626 - val_acc: 81.25% - time: 99.54s
# DOE RunOrder 7 Epoch 7/10 - loss: 0.0905 - train_acc: 93.42% - val_loss: 0.1285 - val_acc: 81.25% - time: 99.03s
# DOE RunOrder 7 Epoch 8/10 - loss: 0.0798 - train_acc: 90.79% - val_loss: 0.1002 - val_acc: 87.50% - time: 104.97s
# DOE RunOrder 7 Epoch 9/10 - loss: 0.0574 - train_acc: 93.42% - val_loss: 0.0847 - val_acc: 87.50% - time: 104.04s
# DOE RunOrder 7 Epoch 10/10 - loss: 0.0454 - train_acc: 94.74% - val_loss: 0.0774 - val_acc: 87.50% - time: 95.64s
# Model weights loaded successfully.
# Test Accuracy: 56.25%
# Test Loss: 0.2946
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 8 Epoch 1/10 - loss: 0.5851 - train_acc: 43.42% - val_loss: 0.5000 - val_acc: 50.00% - time: 100.83s
# DOE RunOrder 8 Epoch 2/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 100.51s
# DOE RunOrder 8 Epoch 3/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.30s
# DOE RunOrder 8 Epoch 4/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 107.76s
# DOE RunOrder 8 Epoch 5/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 98.55s
# DOE RunOrder 8 Epoch 6/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 99.33s
# DOE RunOrder 8 Epoch 7/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 96.82s
# DOE RunOrder 8 Epoch 8/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 99.74s
# DOE RunOrder 8 Epoch 9/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 97.47s
# DOE RunOrder 8 Epoch 10/10 - loss: 0.5000 - train_acc: 50.00% - val_loss: 0.5000 - val_acc: 50.00% - time: 107.12s
# Model weights loaded successfully.
# Test Accuracy: 47.50%
# Test Loss: 0.5250
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 9 Epoch 1/10 - loss: 16.1002 - train_acc: 40.79% - val_loss: 0.7523 - val_acc: 50.00% - time: 98.04s
# DOE RunOrder 9 Epoch 2/10 - loss: 0.7526 - train_acc: 50.00% - val_loss: 0.7967 - val_acc: 50.00% - time: 103.22s
# DOE RunOrder 9 Epoch 3/10 - loss: 1.0358 - train_acc: 36.84% - val_loss: 0.6954 - val_acc: 50.00% - time: 96.49s
# DOE RunOrder 9 Epoch 4/10 - loss: 0.7685 - train_acc: 25.00% - val_loss: 0.6764 - val_acc: 50.00% - time: 99.54s
# DOE RunOrder 9 Epoch 5/10 - loss: 0.7730 - train_acc: 31.58% - val_loss: 0.6454 - val_acc: 87.50% - time: 106.95s
# DOE RunOrder 9 Epoch 6/10 - loss: 0.7445 - train_acc: 42.11% - val_loss: 0.6100 - val_acc: 81.25% - time: 102.62s
# DOE RunOrder 9 Epoch 7/10 - loss: 0.7086 - train_acc: 53.95% - val_loss: 0.5454 - val_acc: 87.50% - time: 98.69s
# DOE RunOrder 9 Epoch 8/10 - loss: 0.6324 - train_acc: 67.11% - val_loss: 0.4668 - val_acc: 87.50% - time: 97.74s
# DOE RunOrder 9 Epoch 9/10 - loss: 0.5080 - train_acc: 76.32% - val_loss: 0.3790 - val_acc: 87.50% - time: 100.23s
# DOE RunOrder 9 Epoch 10/10 - loss: 0.2438 - train_acc: 92.11% - val_loss: 0.3777 - val_acc: 87.50% - time: 97.28s
# Model weights loaded successfully.
# Test Accuracy: 57.50%
# Test Loss: 0.6801
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 10 Epoch 1/10 - loss: 0.4804 - train_acc: 40.79% - val_loss: 0.3462 - val_acc: 50.00% - time: 99.44s
# DOE RunOrder 10 Epoch 2/10 - loss: 0.3117 - train_acc: 50.00% - val_loss: 0.2477 - val_acc: 50.00% - time: 103.01s
# DOE RunOrder 10 Epoch 3/10 - loss: 0.1944 - train_acc: 59.21% - val_loss: 0.1928 - val_acc: 81.25% - time: 99.38s
# DOE RunOrder 10 Epoch 4/10 - loss: 0.1425 - train_acc: 92.11% - val_loss: 0.1932 - val_acc: 75.00% - time: 99.79s
# DOE RunOrder 10 Epoch 5/10 - loss: 0.1498 - train_acc: 82.89% - val_loss: 0.1904 - val_acc: 75.00% - time: 97.64s
# DOE RunOrder 10 Epoch 6/10 - loss: 0.1391 - train_acc: 85.53% - val_loss: 0.1586 - val_acc: 75.00% - time: 106.64s
# DOE RunOrder 10 Epoch 7/10 - loss: 0.1049 - train_acc: 90.79% - val_loss: 0.1184 - val_acc: 87.50% - time: 99.23s
# DOE RunOrder 10 Epoch 8/10 - loss: 0.0752 - train_acc: 94.74% - val_loss: 0.0950 - val_acc: 93.75% - time: 98.20s
# DOE RunOrder 10 Epoch 9/10 - loss: 0.0550 - train_acc: 94.74% - val_loss: 0.0806 - val_acc: 93.75% - time: 102.39s
# DOE RunOrder 10 Epoch 10/10 - loss: 0.0353 - train_acc: 97.37% - val_loss: 0.0773 - val_acc: 87.50% - time: 97.41s
# Model weights loaded successfully.
# Test Accuracy: 56.25%
# Test Loss: 0.2438
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 11 Epoch 1/10 - loss: 16.4456 - train_acc: 47.37% - val_loss: 1.3923 - val_acc: 50.00% - time: 102.68s
# DOE RunOrder 11 Epoch 2/10 - loss: 0.5481 - train_acc: 51.32% - val_loss: 1.4604 - val_acc: 50.00% - time: 101.48s
# DOE RunOrder 11 Epoch 3/10 - loss: 1.8851 - train_acc: 50.00% - val_loss: 0.7007 - val_acc: 50.00% - time: 98.58s
# DOE RunOrder 11 Epoch 4/10 - loss: 0.8597 - train_acc: 6.58% - val_loss: 0.6741 - val_acc: 81.25% - time: 98.47s
# DOE RunOrder 11 Epoch 5/10 - loss: 0.7758 - train_acc: 30.26% - val_loss: 0.6580 - val_acc: 87.50% - time: 99.76s
# DOE RunOrder 11 Epoch 6/10 - loss: 0.7462 - train_acc: 40.79% - val_loss: 0.6391 - val_acc: 62.50% - time: 101.03s
# DOE RunOrder 11 Epoch 7/10 - loss: 0.7549 - train_acc: 35.53% - val_loss: 0.6048 - val_acc: 62.50% - time: 107.75s
# DOE RunOrder 11 Epoch 8/10 - loss: 0.6545 - train_acc: 61.84% - val_loss: 0.5329 - val_acc: 81.25% - time: 100.54s
# DOE RunOrder 11 Epoch 9/10 - loss: 0.5303 - train_acc: 73.68% - val_loss: 0.4077 - val_acc: 93.75% - time: 95.28s
# DOE RunOrder 11 Epoch 10/10 - loss: 0.3567 - train_acc: 85.53% - val_loss: 0.3227 - val_acc: 87.50% - time: 102.37s
# Model weights loaded successfully.
# Test Accuracy: 58.75%
# Test Loss: 0.6994
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
# ...
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 13 Epoch 1/10 - loss: 9.7505 - train_acc: 13.16% - val_loss: 0.6870 - val_acc: 56.25% - time: 96.48s
# DOE RunOrder 13 Epoch 2/10 - loss: 0.7471 - train_acc: 48.68% - val_loss: 0.6994 - val_acc: 50.00% - time: 102.77s
# DOE RunOrder 13 Epoch 3/10 - loss: 0.7969 - train_acc: 3.95% - val_loss: 0.6916 - val_acc: 50.00% - time: 97.72s
# DOE RunOrder 13 Epoch 4/10 - loss: 0.8301 - train_acc: 9.21% - val_loss: 0.6848 - val_acc: 50.00% - time: 106.08s
# DOE RunOrder 13 Epoch 5/10 - loss: 0.8260 - train_acc: 18.42% - val_loss: 0.6600 - val_acc: 87.50% - time: 96.87s
# DOE RunOrder 13 Epoch 6/10 - loss: 0.9085 - train_acc: 35.53% - val_loss: 0.6478 - val_acc: 62.50% - time: 102.41s
# DOE RunOrder 13 Epoch 7/10 - loss: 0.7859 - train_acc: 32.89% - val_loss: 0.6297 - val_acc: 62.50% - time: 97.86s
# DOE RunOrder 13 Epoch 8/10 - loss: 0.8422 - train_acc: 19.74% - val_loss: 0.5904 - val_acc: 62.50% - time: 95.06s
# DOE RunOrder 13 Epoch 9/10 - loss: 0.6446 - train_acc: 64.47% - val_loss: 0.5200 - val_acc: 87.50% - time: 98.87s
# DOE RunOrder 13 Epoch 10/10 - loss: 0.4423 - train_acc: 81.58% - val_loss: 0.5189 - val_acc: 87.50% - time: 108.77s
# Model weights loaded successfully.
# Test Accuracy: 56.25%
# Test Loss: 0.6854
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 14 Epoch 1/10 - loss: 1.1593 - train_acc: 31.58% - val_loss: 0.7732 - val_acc: 50.00% - time: 98.49s
# DOE RunOrder 14 Epoch 2/10 - loss: 0.6726 - train_acc: 51.32% - val_loss: 0.6381 - val_acc: 56.25% - time: 103.28s
# DOE RunOrder 14 Epoch 3/10 - loss: 0.5332 - train_acc: 78.95% - val_loss: 0.5918 - val_acc: 87.50% - time: 104.58s
# DOE RunOrder 14 Epoch 4/10 - loss: 0.4796 - train_acc: 89.47% - val_loss: 0.5722 - val_acc: 75.00% - time: 102.85s
# DOE RunOrder 14 Epoch 5/10 - loss: 0.4303 - train_acc: 90.79% - val_loss: 0.5351 - val_acc: 75.00% - time: 104.92s
# DOE RunOrder 14 Epoch 6/10 - loss: 0.3927 - train_acc: 93.42% - val_loss: 0.4611 - val_acc: 81.25% - time: 96.90s
# DOE RunOrder 14 Epoch 7/10 - loss: 0.3128 - train_acc: 90.79% - val_loss: 0.3727 - val_acc: 87.50% - time: 98.40s
# DOE RunOrder 14 Epoch 8/10 - loss: 0.2361 - train_acc: 93.42% - val_loss: 0.3720 - val_acc: 87.50% - time: 99.77s
# DOE RunOrder 14 Epoch 9/10 - loss: 0.2242 - train_acc: 94.74% - val_loss: 0.3712 - val_acc: 87.50% - time: 97.87s
# DOE RunOrder 14 Epoch 10/10 - loss: 0.2342 - train_acc: 93.42% - val_loss: 0.3705 - val_acc: 87.50% - time: 96.94s
# Model weights loaded successfully.
# Test Accuracy: 52.50%
# Test Loss: 0.6815
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 15 Epoch 1/10 - loss: 1.2240 - train_acc: 11.84% - val_loss: 0.7313 - val_acc: 50.00% - time: 96.02s
# DOE RunOrder 15 Epoch 2/10 - loss: 0.6891 - train_acc: 50.00% - val_loss: 0.6341 - val_acc: 50.00% - time: 99.99s
# DOE RunOrder 15 Epoch 3/10 - loss: 0.5817 - train_acc: 68.42% - val_loss: 0.5995 - val_acc: 75.00% - time: 97.81s
# DOE RunOrder 15 Epoch 4/10 - loss: 0.5297 - train_acc: 88.16% - val_loss: 0.5758 - val_acc: 81.25% - time: 97.97s
# DOE RunOrder 15 Epoch 5/10 - loss: 0.4774 - train_acc: 93.42% - val_loss: 0.5412 - val_acc: 81.25% - time: 102.18s
# DOE RunOrder 15 Epoch 6/10 - loss: 0.4407 - train_acc: 86.84% - val_loss: 0.4863 - val_acc: 81.25% - time: 106.34s
# DOE RunOrder 15 Epoch 7/10 - loss: 0.3627 - train_acc: 93.42% - val_loss: 0.4154 - val_acc: 87.50% - time: 95.51s
# DOE RunOrder 15 Epoch 8/10 - loss: 0.2759 - train_acc: 94.74% - val_loss: 0.3454 - val_acc: 87.50% - time: 101.84s
# DOE RunOrder 15 Epoch 9/10 - loss: 0.2120 - train_acc: 96.05% - val_loss: 0.2918 - val_acc: 87.50% - time: 101.97s
# DOE RunOrder 15 Epoch 10/10 - loss: 0.1712 - train_acc: 94.74% - val_loss: 0.2590 - val_acc: 87.50% - time: 97.50s
# Model weights loaded successfully.
# Test Accuracy: 56.25%
# Test Loss: 0.7299
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=1, bias=True)
#       (1): Sigmoid()
#     )
#   )
# )
# DOE RunOrder 16 Epoch 1/10 - loss: 0.4767 - train_acc: 6.58% - val_loss: 0.2910 - val_acc: 50.00% - time: 97.91s
# DOE RunOrder 16 Epoch 2/10 - loss: 0.2613 - train_acc: 50.00% - val_loss: 0.2345 - val_acc: 50.00% - time: 101.70s
# DOE RunOrder 16 Epoch 3/10 - loss: 0.1957 - train_acc: 65.79% - val_loss: 0.2060 - val_acc: 75.00% - time: 100.20s
# DOE RunOrder 16 Epoch 4/10 - loss: 0.1606 - train_acc: 88.16% - val_loss: 0.1988 - val_acc: 75.00% - time: 101.48s
# DOE RunOrder 16 Epoch 5/10 - loss: 0.1415 - train_acc: 92.11% - val_loss: 0.1893 - val_acc: 75.00% - time: 97.75s
# DOE RunOrder 16 Epoch 6/10 - loss: 0.1235 - train_acc: 88.16% - val_loss: 0.1590 - val_acc: 81.25% - time: 97.38s
# DOE RunOrder 16 Epoch 7/10 - loss: 0.0932 - train_acc: 94.74% - val_loss: 0.1207 - val_acc: 87.50% - time: 106.99s
# DOE RunOrder 16 Epoch 8/10 - loss: 0.0762 - train_acc: 94.74% - val_loss: 0.0962 - val_acc: 87.50% - time: 101.84s
# DOE RunOrder 16 Epoch 9/10 - loss: 0.0557 - train_acc: 92.11% - val_loss: 0.0836 - val_acc: 87.50% - time: 98.05s
# DOE RunOrder 16 Epoch 10/10 - loss: 0.0305 - train_acc: 97.37% - val_loss: 0.0828 - val_acc: 87.50% - time: 96.90s
# Model weights loaded successfully.
# Test Accuracy: 57.50%
# Test Loss: 0.2658
